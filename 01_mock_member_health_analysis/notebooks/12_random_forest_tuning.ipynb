# %% [markdown]
# # Random Forest Hyperparameter Tuning

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd # Load and manipulate tabular data
import numpy as np # Numerical calculations

import matplotlib.pyplot as plt # Create plots

from sklearn.model_selection import train_test_split, GridSearchCV # Split data and tune hyperparameters 
from sklearn.compose import ColumnTransformer # Apply preprocessing by column type
from sklearn.preprocessing import OneHotEncoder # Encode categorical variables
from sklearn.pipeline import Pipeline # Combine preprocessing and modeling steps

from sklearn.ensemble import RandomForestRegressor # Main Day 14 model

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score # Regression metrics

# %% [markdown]
# ## 2. Load Data

# %%
df = pd.read_csv("../data/processed/member_analysis_ready.csv") # Load processed feature dataset

df.head() # Preview data
# Out:
#   member_id  age  gender    region           plan_type  sdoh_risk_score  \
# 0    M00001   69    Male  Suburban  Medicare Advantage             40.7
# 1    M00002   32  Female     Urban                DSNP             80.0
# 2    M00003   89  Female  Suburban  Medicare Advantage             49.6
# 3    M00004   78    Male  Suburban  Medicare Advantage             45.7
# 4    M00005   38    Male  Suburban  Medicare Advantage             32.4
#
#    chronic_condition_count  engagement_score  pcp_attributed_24mo  \
# 0                        2              68.9                    1
# 1                        3              30.4                    0
# 2                        3              86.3                    1
# 3                        4              63.1                    1
# 4                        0              55.6                    0
#
#    prior_awv_count  ...  engagement_group  age_group  high_cost_member  \
# 0                1  ...           Q4_High      65-79                 1
# 1                0  ...            Q1_Low      18-34                 0
# 2                3  ...           Q4_High        80+                 0
# 3                1  ...           Q4_High      65-79                 1
# 4                0  ...           Q4_High      35-49                 0
#
#    chronic_burden_group  sdoh_risk_group prior_awv_group total_acute_visits  \
# 0              Moderate           Q1_Low               1                  2
# 1              Moderate          Q4_High               0                  2
# 2              Moderate               Q2               3                  0
# 3                  High           Q1_Low               1                  3
# 4                   Low           Q1_Low               0                  0
#
#    acute_utilization_group      pcp_status has_acute_utilization
# 0                      Low      Attributed                     1
# 1                      Low  Not Attributed                     1
# 2                      NaN      Attributed                     0
# 3                 Moderate      Attributed                     1
# 4                      NaN  Not Attributed                     0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3. Define target and features

# %%
target = "monthly_cost" # Regression target

drop_cols = [
    "member_id", # ID column; not useful for prediction
    "monthly_cost", # Target column; must be removed from features
    "high_cost_member", # Derived from monthly_cost, so it leaks target information
    "awv_completed" # Excluded to keep baseline cost model clean 
]

X = df.drop(columns = drop_cols) # Create feature matrix
y = df[target] # Create target vector

# %% [markdown]
# ## 4. Detect column types

# %%
categorical_cols = X.select_dtypes(
    include = ["object", "string", "category", "bool"]
).columns.tolist() # Identify categorical variables

numeric_cols = X.select_dtypes(
    include = ["int64", "float64", "int32", "float32"]
).columns.tolist()

print("Categorical columns:", categorical_cols)
print("Numeric columns:", numeric_cols)
# Out:
# Categorical columns: ['gender', 'region', 'plan_type', 'engagement_group', 'age_group', 'chronic_burden_group', 'sdoh_risk_group', 'acute_utilization_group', 'pcp_status']
# Numeric columns: ['age', 'sdoh_risk_score', 'chronic_condition_count', 'engagement_score', 'pcp_attributed_24mo', 'prior_awv_count', 'prior_awv_rate', 'ed_visits', 'ip_admits', 'prior_awv_group', 'total_acute_visits', 'has_acute_utilization']

# %% [markdown]
# ## 5. Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, # Feature Matrix
    y, # Target vector
    test_size = 0.20, # Reserve 20% for testing
    random_state = 42 # Reproducible split 
)

# %% [markdown]
# ## 6. Build preprocessing

# %%
preprocessor = ColumnTransformer( 
    transformers = [
        (
                "cat",
                OneHotEncoder(handle_unknown = "ignore"),
                categorical_cols
        )
    ],
    remainder = "passthrough" # Keep numeric variables unchanged 
)

# %% [markdown]
# ## 7. Build base Random Forest pipeline

# %%
rf_pipeline = Pipeline(
    steps = [
        ("preprocessor", preprocessor), # Encode categorical variables
        (
            "model",
            RandomForestRegressor( 
                random_state=42, # Reproducible model
                n_jobs = 1 # Use all available CPU cores
            )
        )
    ]
)

# %% [markdown]
# ## 8. Define hyperparameter grid

# %%
param_grid = {
    "model__n_estimators" : [200, 200], # Number of trees 
    "model__max_depth" : [5, 10, None], # Maximum tree depth
    "model__min_samples_leaf": [1, 5, 10], # Minimum samples in each leaf
    "model__max_features": ["sqrt", 1.0] # Number of features considered at each split 
}

# %% [markdown]
# ## 9. Run GridSearchCV

# %%
grid_search = GridSearchCV(
    estimator = rf_pipeline, # Pipeline to tune 
    param_grid = param_grid, # Hyperparameter combinations
    scoring = "neg_root_mean_squared_error", # Use RMSE, but sklearn stores it as negative
    cv = 5, # 5-fold cross-validation
    n_jobs = -1, # Use all CPU cores
    verbose = 1  # Show progress 
)

grid_search.fit(X_train, y_train) # Run tuning on training data only
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['gender',
#                                                                           'region',
#                                                                           'plan_type',
#                                                                           'engagement_group',
#                                                                           'age_group',
#                                                                           'chronic_burden_group',
#                                                                           'sdoh_risk_group',
#                                                                           'acute_utilization_group',
#                                                                           'pcp_status'])])),
#                                        ('model',
#                                         RandomForestRegressor(n_jobs=1,
#                                                               random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model__max_depth': [5, 10, None],
#                          'model__max_features': ['sqrt', 1.0],
#                          'model__min_samples_leaf': [1, 5, 10],
#                          'model__n_estimators': [200, 200]},
#              scoring='neg_root_mean_squared_error', verbose=1)

# %% [markdown]
# ## 10. Review best parameters

# %%
print("Best parameters:")
print(grid_search.best_params_)

print("Best CV RMSE:")
print(-grid_search.best_score_)
# Out:
# Best parameters:
# {'model__max_depth': 10, 'model__max_features': 1.0, 'model__min_samples_leaf': 5, 'model__n_estimators': 200}
# Best CV RMSE:
# 561.6658213381522

# %% [markdown]
# ## 11. Evaluate tuned model on test set

# %%
best_rf_model = grid_search.best_estimator_ # Extract best pipeline 

y_train_pred = best_rf_model.predict(X_train) # Predict training set
y_test_pred = best_rf_model.predict(X_test) # Predict test set

train_mae = mean_absolute_error(y_train, y_train_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

tuned_rf_results = pd.DataFrame({
    "Dataset": ["Train", "Test"],
    "MAE": [train_mae, test_mae],
    "RMSE": [train_rmse, test_rmse],
    "r2": [train_r2, test_r2]

})

tuned_rf_results
# Out:
#   Dataset         MAE        RMSE        r2
# 0   Train  266.821733  424.242612  0.886525
# 1    Test  389.721734  665.608321  0.755596

# %% [markdown]
# ## 12. Compare baseline vs tuned Random Forest

# %%
rf_comparison = pd.DataFrame({
    "Model": [
        "Baseline Random Forest",
        "Tuned Random Forest"
    ],
    "Test MAE": [
        390.50,
        test_mae
    ],
    "Test RMSE": [
        665.28,
        test_rmse
    ],
    "Test R2": [
        0.76,
        test_r2
    ]
})
rf_comparison
# Out:
#                     Model    Test MAE   Test RMSE   Test R2
# 0  Baseline Random Forest  390.500000  665.280000  0.760000
# 1     Tuned Random Forest  389.721734  665.608321  0.755596

# %% [markdown]
# ## 13. Actual vs predicted plot

# %%
plt.figure(figsize = (8, 6))

plt.scatter(y_test, y_test_pred, alpha = 0.5)

plt.xlabel("Actual Monthly Cost")
plt.ylabel("Predicted Monthly Cost")
plt.title("Tuned Random Forest: Actual vs Predicted Monthly Cost")

plt.show()

# %% [markdown]
# ## 14. Residual plot

# %%
residuals = y_test - y_test_pred # Actual minus predicted

plt.figure(figsize = (8,6))

plt.scatter(y_test_pred, residuals, alpha = 0.5)
plt.axhline(0, linestyle = "--")

plt.xlabel("Predicted Monthly Cost")
plt.ylabel("Residual")
plt.title("Tuned Random Forest: Residuals vs Predicted Monthly Cost")

plt.show()

# %% [markdown]
# ## 15. Feature importance from tuned model

# %%
trained_preprocessor = best_rf_model.named_steps["preprocessor"] # Access fitted preprocessor
trained_rf = best_rf_model.named_steps["model"] # Access fitted tuned Random Forest

feature_names = trained_preprocessor.get_feature_names_out() # Get transformed feature names

importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": trained_rf.feature_importances_
}).sort_values(by = "importance", ascending = False)

importance_df.head(20)
# Out:
#                                   feature  importance
# 17         cat__chronic_burden_group_High    0.282253
# 38                   remainder__ip_admits    0.264656
# 32     remainder__chronic_condition_count    0.219986
# 40          remainder__total_acute_visits    0.070284
# 33            remainder__engagement_score    0.024111
# 5                     cat__plan_type_DSNP    0.020873
# 30                         remainder__age    0.019133
# 37                   remainder__ed_visits    0.016882
# 31             remainder__sdoh_risk_score    0.015246
# 18          cat__chronic_burden_group_Low    0.014519
# 19     cat__chronic_burden_group_Moderate    0.011693
# 6                 cat__plan_type_Medicaid    0.006300
# 25       cat__acute_utilization_group_Low    0.003426
# 24      cat__acute_utilization_group_High    0.002599
# 26  cat__acute_utilization_group_Moderate    0.001717
# 27       cat__acute_utilization_group_nan    0.001535
# 41       remainder__has_acute_utilization    0.001517
# 4                       cat__region_Urban    0.001463
# 2                       cat__region_Rural    0.001461
# 29         cat__pcp_status_Not Attributed    0.001342

# %% [markdown]
# ## 16. Plot top feature importances

# %%
top_features = importance_df.head(15).sort_values(by="importance") # Sort for horizontal plot

plt.figure(figsize=(8, 6))

plt.barh(top_features["feature"], top_features["importance"])

plt.xlabel("Feature Importance")
plt.title("Top 15 Tuned Random Forest Feature Importances")

plt.show()

# %% [markdown]
# ## 17. Findings

# %% [markdown]
# 1. Random Forest hyperparameter tuning was performed using 5-fold cross-validation.
#
# 2. The tuning focused on number of trees, maximum tree depth, minimum samples per leaf, and number of features considered at each split.
#
# 3. The best model was selected using cross-validated RMSE.
#
# 4. Test MAE, test RMSE, and test R² were used to evaluate final performance on the held-out test set.
#
# 5. If the tuned Random Forest improves test RMSE or test R² compared with the baseline Random Forest, the tuning improved generalization.
#
# 6. If the tuned model performs similarly to or worse than the baseline model, that means the original baseline settings were already reasonable or the tuning grid was not broad enough.
#
# 7. Feature importance values show predictive usefulness inside the fitted Random Forest model, not causal effects.
#
# 8. Because this project uses synthetic data, these findings reflect the data-generation assumptions rather than real-world healthcare evidence.
